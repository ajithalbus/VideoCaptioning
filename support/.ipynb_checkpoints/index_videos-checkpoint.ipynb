# %%
from os import listdir,rename
import numpy as np
import pickle as pkl
import shutil

# %%
a=[i.split('.')[0] for i in listdir('./features/test/')]

# %%
indexs=np.array(zip(range(1300,1970),a))

# %%
np.save(arr=indexs,file='./clip_index/testIndex.npy')

# %%
len(a)
# Out:
# 670

# %%
np.load('../captions/token_test.pkl')
# Out:
# [[1848,
#   array(['a', 'bird', 'in', 'a', 'sink', 'keeps', 'getting', 'under', 'the',
#          'running', 'water', 'from', 'a', 'faucet'], dtype='|S7')],
#  [1848, array(['a', 'bird', 'is', 'bathing', 'in', 'a', 'sink'], dtype='|S7')],
#  [1848,
#   array(['a', 'bird', 'is', 'splashing', 'around', 'under', 'a', 'running',
#          'faucet'], dtype='|S9')],
#  [1848, array(['a', 'bird', 'is', 'bathing', 'in', 'a', 'sink'], dtype='|S7')],
#  [1848, array(['a', 'bird', 'is', 'standing', 'in', 'a', 'sink', 'drinking',
#          'water', 'that', 'is', 'pouring', 'out', 'of', 'the', 'facet'],
#         dtype='|S8')],
#  [1848, array(['a', 'faucet', 'is', 'running', 'while', 'a', 'bird', 'stands',
#          'in', 'the', 'sink', 'below'], dtype='|S7')],
#  [1848,
#   array(['a', 'bird', 'is', 'playing', 'in', 'a', 'sink', 'with', 'running',
#          'water'], dtype='|S7')],
#  [1848,
#   array(['a', 'bird', 'is', 'playing', 'in', 'tap', 'water'], dtype='|S7')],
#  [1848,
#   array(['a', 'bird', 'is', 'bathing', 'in', 'the', 'sink'], dtype='|S7')],
#  [1848, array(['a', 'bird', 'is', 'taking', 'a', 'bath'], dtype='|S6')],
#  [1848, array(['a', 'bird', 'is', 'taking', 'a', 'shower', 'in', 'a', 'sink'],
#         dtype='|S6')],
#  [1848,
#   array(['a', 'bird', 'is', 'showering', 'in', 'the', 'sink'], dtype='|S9')],
#  [1848, array(['the', 'bird', 'is', 'taking', 'a', 'bath', 'under', 'the',
#          'faucet'], dtype='|S6')],
#  [1848,
#   array(['a', 'parakeet', 'is', 'taking', 'a', 'shower', 'in', 'a', 'sink'],
#         dtype='|S8')],
#  [1848, array(['a', 'bird', 'gets', 'washed'], dtype='|S6')],
#  [1848,
#   array(['a', 'bird', 'is', 'having', 'a', 'bath', 'in', 'the', 'kitchen',
#          'sink'], dtype='|S7')],
#  [1848, array(['a', 'bird', 'is', 'bathing', 'in', 'a', 'sink', 'under',
#          'running', 'water'], dtype='|S7')],
#  [1848, array(['the', 'bird', 'is', 'drinking', 'water'], dtype='|S8')],
#  [1848, array(['a', 'bird', 'walks', 'under', 'a', 'running', 'tap', 'in', 'a',
#          'sink'], dtype='|S7')],
#  [1848,
#   array(['a', 'parrot', 'is', 'playing', 'inside', 'the', 'wash', 'basin'],
#         dtype='|S7')],
#  [1848,
#   array(['a', 'bird', 'in', 'a', 'sink', 'n', 'playing', 'with', 'water'],
#         dtype='|S7')],
#  [1848, array(['a', 'bird', 'is', 'playing', 'in', 'a', 'sink'], dtype='|S7')],
#  [1848,
#   array(['a', 'cockatiel', 'in', 'a', 'kitchen', 'sink', 'playing', 'under',
#          'the', 'running', 'water'], dtype='|S9')],
#  [1848, array(['a', 'bird', 'is', 'taking', 'a', 'bath', 'in', 'a', 'sink'],
#         dtype='|S6')],
#  [1848,
#   array(['a', 'bird', 'is', 'playing', 'in', 'the', 'sink'], dtype='|S7')],
#  [1848,
#   array(['the', 'white', 'birt', 'took', 'a', 'bath', 'in', 'the', 'sink'],
#         dtype='|S5')],
#  [1848, array(['a', 'bird', 'is', 'playing'], dtype='|S7')],
#  [1848,
#   array(['the', 'bird', 'is', 'taking', 'a', 'bath', 'in', 'the', 'sink'],
#         dtype='|S6')],
#  [1848, array(['a', 'bird', 'is', 'drinking', 'out', 'of', 'the', 'sink'],
#         dtype='|S8')],
#  [1719, array(['a', 'plane', 'flying', 'in', 'the', 'sky'], dtype='|S6')],
#  [1719, array(['a', 'commercial', 'plane', 'flying'], dtype='|S10')],
#  [1719, array(['a', 'jet', 'is', 'flying'], dtype='|S6')],
#  [1719, array(['a', 'large', 'jet', 'is', 'flying', 'through', 'the', 'sky'],
#         dtype='|S7')],
#  [1719, array(['a', 'passenger', 'plane', 'flies', 'through', 'the', 'air'],
#         dtype='|S9')],
#  [1719, array(['a', 'plane', 'flies', 'through', 'the', 'air'], dtype='|S7')],
#  [1719,
#   array(['a', 'plane', 'is', 'flying', 'in', 'the', 'air'], dtype='|S6')],
#  [1719, array(['a', 'plane', 'is', 'flying'], dtype='|S6')],
#  [1719,
#   array(['a', 'south', 'african', 'airways', 'plane', 'is', 'flying', 'in',
#          'a', 'blue', 'sky'], dtype='|S7')],
#  [1719,
#   array(['an', 'aeroplane', 'is', 'flying', 'in', 'the', 'air'], dtype='|S9')],
#  [1719,
#   array(['an', 'airplane', 'is', 'flying', 'in', 'the', 'air'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'is', 'flying', 'in', 'the', 'clear', 'sky'],
#         dtype='|S8')],
#  [1719,
#   array(['an', 'airplane', 'is', 'flying', 'in', 'the', 'sky'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'is', 'flying'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'is', 'flying'], dtype='|S8')],
#  [1719, array(['the', 'plane', 'flew', 'in', 'the', 'sky'], dtype='|S5')],
#  [1719, array(['the', 'plane', 'is', 'soaring', 'through', 'the', 'air'],
#         dtype='|S7')],
#  [1719,
#   array(['the', 'south', 'african', 'jet', 'banked', 'itself', 'in', 'the',
#          'air'], dtype='|S7')],
#  [1719, array(['the', 'airplane', 'is', 'flying', 'in', 'air'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'flying'], dtype='|S8')],
#  [1719, array(['a', 'south', 'african', 'airplane', 'flying', 'sideways', 'in',
#          'the', 'sky'], dtype='|S8')],
#  [1719, array(['the', 'avi\xc3\xb3n', 'airplane', 'is', 'flying', 'high', 'in',
#          'the', 'sky'], dtype='|S8')],
#  [1719, array(['a', 'plane', 'is', 'flying'], dtype='|S6')],
#  [1719, array(['an', 'aeroplane', 'flying', 'in', 'the', 'sky'], dtype='|S9')],
#  [1719, array(['an', 'aeroplane', 'is', 'flying'], dtype='|S9')],
#  [1719, array(['an', 'aeroplane', 'is', 'flying'], dtype='|S9')],
#  [1719,
#   array(['a', 'flight', 'is', 'flying', 'in', 'the', 'sky'], dtype='|S6')],
#  [1719,
#   array(['a', 'south', 'african', 'flight', 'is', 'flying'], dtype='|S7')],
#  [1719, array(['an', 'airplane', 'is', 'flying', 'with', 'blue', 'sky', 'in',
#          'the', 'background'], dtype='|S10')],
#  [1719, array(['aeroplane', 'is', 'fling', 'in', 'midair'], dtype='|S9')],
#  [1719,
#   array(['an', 'airplane', 'is', 'flying', 'in', 'the', 'air'], dtype='|S8')],
#  [1719, array(['south', 'african', 'aeroplane', 'js', 'moving', 'in', 'the',
#          'air'], dtype='|S9')],
#  [1719, array(['a', 'plane', 'is', 'flying', 'in', 'air'], dtype='|S6')],
#  [1719, array(['a', 'commercial', 'jet', 'if', 'flying'], dtype='|S10')],
#  [1719, array(['an', 'airplane', 'flying', 'in', 'the', 'sky'], dtype='|S8')],
#  [1719,
#   array(['an', 'airoplane', 'is', 'flying', 'in', 'the', 'sky'], dtype='|S9')],
#  [1719, array(['a', 'flight', 'is', 'flying'], dtype='|S6')],
#  [1719, array(['a', 'clip', 'showing', 'an', 'south', 'african', 'airline',
#          'plane', 'flying', 'in', 'air'], dtype='|S7')],
#  [1719,
#   array(['a', 'south', 'african', 'airplane', 'is', 'flying'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'flying', 'in', 'the', 'sky'], dtype='|S8')],
#  [1719, array(['an', 'airplane', 'is', 'flying', 'through', 'the', 'air'],
#         dtype='|S8')],
#  [1719, array(['an', 'airplane', 'is', 'flying'], dtype='|S8')],
#  [1719,
#   array(['an', 'plane', 'is', 'flying', 'in', 'the', 'sky'], dtype='|S6')],
#  [1719, array(['a', 'flying', 'airplane'], dtype='|S8')],
#  [1719, array(['a', 'airplane', 'in', 'the', 'air'], dtype='|S8')],
#  [1719, array(['a', 'south', 'american', 'plane', 'takes', 'a', 'turn', 'in',
#          'air'], dtype='|S8')],
#  [1719, array(['the', 'plane', 'is', 'soaring', 'through', 'the', 'air'],
#         dtype='|S7')],
#  [1719, array(['an', 'avion', 'airoplane', 'is', 'flying'], dtype='|S9')],
#  [1719, array(['a', 'aeroplane', 'is', 'flying'], dtype='|S9')],
#  [1719, array(['a', 'plain', 'is', 'fly', 'in', 'the', 'sky'], dtype='|S5')],
#  [1719, array(['avion', 'airplane'], dtype='|S8')],
#  [1640,
#   array(['a', 'man', 'playing', 'a', 'guitar', 'outside', 'his', 'house'],
#         dtype='|S7')],
#  [1640,
#   array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'on', 'the', 'patio'],
#         dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'seated', 'outside',
#          'a', 'restaurant'], dtype='|S10')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'while', 'sitting',
#          'down'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'an', 'acoustic', 'guitar',
#          'outdoors'], dtype='|S8')],
#  [1640, array(['a', 'man', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'plays', 'a', 'guitar'], dtype='|S6')],
#  [1640, array(['a', 'man', 'plays', 'guitar'], dtype='|S6')],
#  [1640, array(['a', 'person', 'is', 'performing', 'with', 'his', 'guitar'],
#         dtype='|S10')],
#  [1640, array(['a', 'seated', 'man', 'plays', 'guitar'], dtype='|S6')],
#  [1640,
#   array(['a', 'sitting', 'man', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['the', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['the', 'man', 'is', 'plying', 'his', 'guitar', 'on', 'the',
#          'patio'], dtype='|S6')],
#  [1640, array(['the', 'man', 'played', 'his', 'guitar'], dtype='|S6')],
#  [1640, array(['a', 'man', 'is', 'playing', 'an', 'electric', 'guitar'],
#         dtype='|S8')],
#  [1640, array(['a', 'man', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'guitar', 'outside', 'of', 'a',
#          'store'], dtype='|S7')],
#  [1640, array(['the', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'plays', 'a', 'guitar'], dtype='|S6')],
#  [1640, array(['the', 'man', 'is', 'playing', 'music', 'on', 'a', 'guitar',
#          'sitting', 'on', 'a', 'stool'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'playing', 'an', 'instrument'], dtype='|S10')],
#  [1640, array(['a', 'man', 'is', 'playing', 'music', 'through', 'fiddle'],
#         dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['an', 'old', 'man', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640,
#   array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'outside'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'enjoying', 'himself', 'as', 'he', 'plays',
#          'the', 'guitar'], dtype='|S8')],
#  [1640, array(['a', 'person', 'is', 'playing', 'guitar', 'righ', 'now'],
#         dtype='|S7')],
#  [1640, array(['a', 'man', 'playing', 'electric', 'gutar', 'at', 'a', 'party'],
#         dtype='|S8')],
#  [1640, array(['a', 'man', 'playing', 'his', 'electric', 'guitar', 'at', 'a',
#          'home', 'party', 'outside'], dtype='|S8')],
#  [1640, array(['a', 'man', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'guy', 'is', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640,
#   array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'outside'], dtype='|S7')],
#  [1640,
#   array(['a', 'man', 'is', 'happily', 'playing', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['the', 'man', 'played', 'his', 'guitar', 'at', 'the', 'party'],
#         dtype='|S6')],
#  [1640, array(['a', 'band', 'is', 'performing', 'on', 'a', 'stage', 'outside'],
#         dtype='|S10')],
#  [1640, array(['a', 'man', 'is', 'sitting', 'outdoors', 'playing', 'an',
#          'electric', 'guitar'], dtype='|S8')],
#  [1640,
#   array(['a', 'man', 'is', 'playing', 'a', 'guitar', 'outside'], dtype='|S7')],
#  [1640, array(['the', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640, array(['a', 'man', 'is', 'playing', 'the', 'guitar'], dtype='|S7')],
#  [1640,
#   array(['a', 'man', 'is', 'playing', 'an', 'electric', 'guitar', 'outside',
#          'a', 'home'], dtype='|S8')],
#  [1640,
#   array(['he', 'is', 'playing', 'guitar', 'and', 'not', 'interested', 'in',
#          'any', 'drink'], dtype='|S10')],
#  [1640, array(['a', 'man', 'plays', 'the', 'guitar'], dtype='|S6')],
#  [1640, array(['a', 'man', 'is', 'playing', 'violin'], dtype='|S7')],
#  [1640, array(['a', 'man', 'strummed', 'his', 'guitar', 'on', 'his', 'patio'],
#         dtype='|S8')],
#  [1604, array(['a', 'woman', 'cuts', 'an', 'oion'], dtype='|S5')],
#  [1604, array(['a', 'girl', 'is', 'cutting', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'girl', 'is', 'cutting', 'an', 'onion'], dtype='|S7')],
#  [1604,
#   array(['a', 'girl', 'is', 'cutting', 'onion', 'into', 'small', 'pieces'],
#         dtype='|S7')],
#  [1604,
#   array(['a', 'girl', 'is', 'dicing', 'up', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['a', 'woman', 'chops', 'a', 'white', 'onion'], dtype='|S5')],
#  [1604,
#   array(['a', 'woman', 'cuts', 'and', 'dices', 'an', 'onion'], dtype='|S5')],
#  [1604, array(['a', 'woman', 'is', 'chopping', 'an', 'onion', 'into', 'small',
#          'pieces'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'chopping', 'an', 'onion', 'slice', 'into',
#          'fine', 'pieces'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'cutting', 'onions'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'a', 'onion'], dtype='|S7')],
#  [1604,
#   array(['a', 'woman', 'is', 'slicing', 'some', 'vegetables'], dtype='|S10')],
#  [1604, array(['a', 'woman', 'slices', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['an', 'onion', 'is', 'chopped', 'up'], dtype='|S7')],
#  [1604, array(['the', 'cook', 'is', 'dicing', 'onions'], dtype='|S6')],
#  [1604, array(['the', 'girl', 'is', 'slicing', 'an', 'onion'], dtype='|S7')],
#  [1604,
#   array(['a', 'woman', 'is', 'cutting', 'the', 'tomato', 'into', 'pieces'],
#         dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'young', 'woman', 'cutting', 'an', 'onion', 'to', 'make',
#          'salsa'], dtype='|S7')],
#  [1604, array(['a', 'girl', 'is', 'chopping', 'onions'], dtype='|S8')],
#  [1604, array(['a', 'girl', 'is', 'slicing', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'lady', 'is', 'chopping', 'onions'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'cuts', 'an', 'onion'], dtype='|S5')],
#  [1604, array(['a', 'woman', 'cutting', 'an', 'onion'], dtype='|S7')],
#  [1604,
#   array(['a', 'woman', 'in', 'a', 'red', 'dress', 'chopping', 'tomatoes'],
#         dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'chopping', 'onions'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'chopping', 'onions'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'chopping', 'up', 'onions'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'cutting', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'cutting', 'onions'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'dicing', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['a', 'woman', 'is', 'dicing', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'a', 'salsa'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'an', 'onion'], dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'and', 'chopping', 'up', 'an',
#          'onion'], dtype='|S8')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'and', 'dicing', 'an', 'onion'],
#         dtype='|S7')],
#  [1604,
#   array(['a', 'woman', 'is', 'slicing', 'some', 'tomatoes'], dtype='|S8')],
#  [1604,
#   array(['a', 'woman', 'is', 'slicing', 'some', 'vegetables'], dtype='|S10')],
#  [1604,
#   array(['a', 'woman', 'is', 'slicing', 'some', 'vegitable'], dtype='|S9')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'then', 'dicing', 'an', 'onion'],
#         dtype='|S7')],
#  [1604, array(['a', 'woman', 'is', 'slicing', 'vegetables'], dtype='|S10')],
#  [1604, array(['the', 'girl', 'sliced', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['the', 'girl', 'sliced', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['the', 'lady', 'is', 'slicing', 'onions'], dtype='|S7')],
#  [1604, array(['the', 'woman', 'is', 'dicing', 'an', 'onion'], dtype='|S6')],
#  [1604, array(['woman', 'teaches', 'on', 'how', 'to', 'cook', 'salsa'],
#         dtype='|S7')],
#  [1604, array(['a', 'lady', 'is', 'cutting', 'onion', 'with', 'the', 'knife'],
#         dtype='|S7')],
#  [1478,
#   array(['a', 'woman', 'is', 'putting', 'make', 'up', 'on', 'her', 'face'],
#         dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'putting', 'makeup', 'on', 'her', 'face'],
#         dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'putting', 'on', 'makeup'], dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'doing', 'facial'], dtype='|S6')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup', 'to', 'her', 'face'],
#         dtype='|S8')],
#  [1478,
#   array(['a', 'woman', 'is', 'applying', 'cosmetics', 'to', 'her', 'face'],
#         dtype='|S9')],
#  [1478, array(['a', 'woman', 'explains', 'how', 'to', 'apply', 'makeup'],
#         dtype='|S8')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup'], dtype='|S8')],
#  [1478, array(['a', 'woman', 'applies', 'a', 'concealer', 'to', 'the', 'lower',
#          'portion', 'of', 'her', 'right', 'cheek', 'and', 'blends', 'it',
#          'using', 'her', 'fingers', 'to', 'get', 'a', 'chiseled', 'look'],
#         dtype='|S9')],
#  [1478, array(['a', 'lady', 'rubbing', 'makeup', 'on'], dtype='|S7')],
#  [1478, array(['the', 'lade', 'applied', 'foundation'], dtype='|S10')],
#  [1478, array(['a', 'woman', 'applies', 'make', 'up', 'to', 'her', 'face'],
#         dtype='|S7')],
#  [1478, array(['the', 'woman', 'is', 'putting', 'on', 'makeup'], dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup'], dtype='|S8')],
#  [1478, array(['a', 'lady', 'put', 'foundation', 'on', 'her', 'cheek'],
#         dtype='|S10')],
#  [1478,
#   array(['a', 'lady', 'showing', 'her', 'face', 'and', 'putting', 'makeup'],
#         dtype='|S7')],
#  [1478, array(['a', 'girl', 'is', 'standing'], dtype='|S8')],
#  [1478, array(['a', 'lady', 'is', 'doing', 'makeup'], dtype='|S6')],
#  [1478, array(['a', 'woman', 'applies', 'makeup', 'to', 'her', 'jaw', 'line'],
#         dtype='|S7')],
#  [1478, array(['a', 'woman', 'demonstrates', 'applying', 'facial', 'products'],
#         dtype='|S12')],
#  [1478,
#   array(['a', 'woman', 'demonstrates', 'how', 'to', 'put', 'on', 'makeup'],
#         dtype='|S12')],
#  [1478,
#   array(['a', 'woman', 'telling', 'how', 'to', 'do', 'makeup', 'to', 'face'],
#         dtype='|S7')],
#  [1478, array(['a', 'women', 'showing', 'how', 'to', 'makeup'], dtype='|S7')],
#  [1478, array(['kim', 'kardashian', 'smokey', 'eyes'], dtype='|S10')],
#  [1478,
#   array(['the', 'girl', 'is', 'explaine', 'the', 'healthcare'], dtype='|S10')],
#  [1478,
#   array(['woman', 'instructing', 'how', 'to', 'do', 'makeup'], dtype='|S11')],
#  [1478, array(['a', 'girl', 'doing', 'make', 'up'], dtype='|S5')],
#  [1478, array(['a', 'girl', 'illustration', 'on', 'applying', 'makeup'],
#         dtype='|S12')],
#  [1478, array(['a', 'kim', 'kardashian', 'mokey', 'eyes'], dtype='|S10')],
#  [1478, array(['a', 'lady', 'giving', 'the', 'beauty', 'tips', 'about', 'the',
#          'face'], dtype='|S6')],
#  [1478, array(['a', 'lady', 'is', 'doing', 'make', 'up', 'on', 'her', 'face'],
#         dtype='|S5')],
#  [1478, array(['a', 'lady', 'is', 'doing', 'makeup'], dtype='|S6')],
#  [1478, array(['a', 'lady', 'is', 'giving', 'tips', 'on', 'how', 'to', 'do',
#          'the', 'make', 'up'], dtype='|S6')],
#  [1478, array(['a', 'woman', 'applies', 'makeup', 'to', 'her', 'face'],
#         dtype='|S7')],
#  [1478, array(['a', 'woman', 'demonstrates', 'how', 'to', 'apply', 'makeup'],
#         dtype='|S12')],
#  [1478,
#   array(['a', 'woman', 'doing', 'some', 'sort', 'of', 'makeup', 'on', 'her',
#          'face'], dtype='|S6')],
#  [1478,
#   array(['a', 'woman', 'is', 'applying', 'face', 'makeup'], dtype='|S8')],
#  [1478,
#   array(['a', 'woman', 'is', 'applying', 'face', 'makeup'], dtype='|S8')],
#  [1478,
#   array(['a', 'woman', 'is', 'applying', 'make', 'up', 'on', 'her', 'face'],
#         dtype='|S8')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup', 'to', 'her', 'face'],
#         dtype='|S8')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup', 'to', 'her', 'face'],
#         dtype='|S8')],
#  [1478, array(['a', 'woman', 'is', 'applying', 'makeup'], dtype='|S8')],
#  [1478,
#   array(['a', 'woman', 'is', 'applying', 'something', 'on', 'her', 'face'],
#         dtype='|S9')],
#  [1478,
#   array(['a', 'woman', 'is', 'giving', 'makeup', 'advice'], dtype='|S6')],
#  [1478,
#   array(['a', 'woman', 'is', 'making', 'up', 'her', 'face'], dtype='|S6')],
#  [1478, array(['a', 'woman', 'is', 'placing', 'makeup', 'on', 'her', 'face'],
#         dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'putting', 'on', 'makeup'], dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'putting', 'on', 'makeup'], dtype='|S7')],
#  [1478, array(['a', 'woman', 'is', 'putting', 'on', 'makeup'], dtype='|S7')],
#  [1478,
#   array(['a', 'woman', 'is', 'showing', 'how', 'to', 'apply', 'foundation'],
#         dtype='|S10')],
#  [1478, array(['a', 'woman', 'is', 'showing', 'makeup', 'tips'], dtype='|S7')],
#  [1478, array(['a', 'woman', 'shows', 'how', 'to', 'create', 'a', 'kim',
#          'kardasian', 'makeover', 'look'], dtype='|S9')],
#  [1478, array(['a', 'young', 'womans', 'beautifully', 'madeup', 'eyes'],
#         dtype='|S11')],
#  [1478, array(['kim', 'kardashian', 'makeup', 'on', 'face'], dtype='|S10')],
#  [1478, array(['the', 'woman', 'is', 'applying', 'makeup'], dtype='|S8')],
#  [1478,
#   array(['a', 'girl', 'is', 'teaching', 'about', 'someone'], dtype='|S8')],
#  [1478, array(['a', 'lady', 'is', 'doing', 'make', 'up'], dtype='|S5')],
#  [1478, array(['an', 'women', 'eyes'], dtype='|S5')],
#  [1478, array(['the', 'girl', 'is', 'giving', 'speech'], dtype='|S6')],
#  [1478, array(['a', 'lady', 'is', 'doing', 'make', 'up'], dtype='|S5')],
#  [1478, array(['this', 'video', 'will', 'show', 'you', 'how', 'to', 'do', 'a',
#          'complete', 'facial', 'makeover', 'so', 'you', 'can', 'look',
#          'like', 'a', 'star', 'in', 'no', 'time'], dtype='|S8')],
#  [1809, array(['a', 'band', 'is', 'performing', 'for', 'a', 'large', 'crowd'],
#         dtype='|S10')],
#  [1809, array(['a', 'band', 'is', 'performing', 'on', 'a', 'stage', 'outside'],
#         dtype='|S10')],
#  [1809,
#   array(['a', 'band', 'is', 'performing', 'out', 'stage'], dtype='|S10')],
#  [1809,
#   array(['a', 'band', 'is', 'playing', 'for', 'a', 'group', 'of', 'people'],
#         dtype='|S7')],
#  [1809, array(['a', 'band', 'is', 'playing', 'outside'], dtype='|S7')],
#  [1809, array(['a', 'band', 'is', 'playing', 'to', 'a', 'large', 'crowd'],
#         dtype='|S7')],
#  [1809,
#   array(['a', 'band', 'on', 'stage', 'is', 'playing', 'in', 'front', 'of',
#          'a', 'large', 'crowd'], dtype='|S7')],
#  [1809, array(['a', 'band', 'performs', 'on', 'a', 'stage'], dtype='|S8')],
#  [1809,
#   array(['a', 'band', 'plays', 'for', 'a', 'large', 'crowd'], dtype='|S5')],
#  [1809,
#   array(['a', 'band', 'plays', 'in', 'front', 'of', 'a', 'huge', 'crowd'],
#         dtype='|S5')],
#  [1809, array(['a', 'band', 'plays', 'on', 'stage', 'outside'], dtype='|S7')],
#  [1809, array(['a', 'rock', 'band', 'is', 'performing', 'on', 'stage', 'in',
#          'front', 'of', 'a', 'large', 'gathering', 'of', 'people'],
#         dtype='|S10')],
#  [1809, array(['men', 'are', 'playing', 'music', 'in', 'the', 'street'],
#         dtype='|S7')],
#  [1809, array(['people', 'are', 'playing', 'music'], dtype='|S7')],
#  [1809, array(['the', 'band', 'performed', 'for', 'a', 'large', 'outside',
#          'crowd'], dtype='|S9')],
#  [1809, array(['the', 'band', 'performed', 'outside', 'for', 'a', 'large',
#          'crowd'], dtype='|S9')],
#  [1809, array(['the', 'band', 'was', 'playing', 'in', 'front', 'of', 'an',
#          'audience'], dtype='|S8')],
#  [1809, array(['the', 'some', 'boys', 'are', 'sing', 'and', 'dancing'],
#         dtype='|S7')],
#  [1809,
#   array(['a', 'band', 'plays', 'an', 'outdoor', 'concert'], dtype='|S7')],
#  [1809, array(['a', 'view', 'of', 'a', 'rock', 'band'], dtype='|S4')],
#  [1809,
#   array(['a', 'band', 'is', 'playing', 'on', 'a', 'stage'], dtype='|S7')],
#  [1809, array(['a', 'band', 'is', 'playing', 'onstage'], dtype='|S7')],
#  [1809, array(['a', 'band', 'is', 'performing'], dtype='|S10')],
#  [1809, array(['a', 'band', 'is', 'performing'], dtype='|S10')],
#  [1809, array(['a', 'band', 'is', 'performing', 'on', 'stage', 'in', 'front',
#          'of', 'a', 'large', 'crowd'], dtype='|S10')],
#  [1809, array(['a', 'band', 'is', 'performing', 'on', 'a', 'stage', 'outside'],
#         dtype='|S10')],
#  [1809,
#   array(['a', 'band', 'is', 'playing', 'on', 'a', 'stage'], dtype='|S7')],
#  [1809, array(['a', 'band', 'performing', 'on', 'a', 'stage'], dtype='|S10')],
#  [1809, array(['a', 'band', 'is', 'performing', 'onstage', 'outside'],
#         dtype='|S10')],
#  [1809, array(['cool', 'band', 'is', 'playng', 'on', 'a', 'stage', 'outside'],
#         dtype='|S7')],
#  [1809,
#   array(['a', 'band', 'is', 'performing', 'in', 'frint', 'of', 'a', 'huge',
#          'crowd'], dtype='|S10')],
#  [1809,
#   array(['all', 'people', 'playing', 'music', 'instruments'], dtype='|S11')],
#  [1809, array(['a', 'short', 'clip', 'about', 'rock', 'movie'], dtype='|S5')],
#  [1809, array(['people', 'are', 'at', 'a', 'concert'], dtype='|S7')],
#  [1809, array(['a', 'man', 'is', 'playing', 'a', 'guitar'], dtype='|S7')],
#  [1809, array(['a', 'crowd', 'of', 'people', 'enjoying', 'a', 'musical',
#          'concert'], dtype='|S8')],
#  [1809, array(['a', 'short', 'clip', 'from', 'the', 'rockon', 'showing', 'the',
#          'stars', 'in', 'it'], dtype='|S7')],
#  [1809, array(['a', 'musical', 'group', 'givinig', 'his', 'rock', 'perfomance',
#          'on', 'stage'], dtype='|S10')],
#  [1809, array(['peoples', 'singing', 'song'], dtype='|S7')],
#  [1809,
#   array(['a', 'rock', 'band', 'plays', 'music', 'on', 'stage'], dtype='|S5')],
#  [1809, array(['a', 'band', 'is', 'performing', 'outdoors', 'surrounded', 'by',
#          'a', 'large', 'crowd'], dtype='|S10')],
#  [1809,
#   array(['group', 'of', 'boys', 'playing', 'instruments'], dtype='|S11')],
#  [1809, array(['rock', 'the', 'entire', 'boys', 'group'], dtype='|S6')],
#  [1809, array(['a', 'ban', 'is', 'performing', 'on', 'stage', 'outside'],
#         dtype='|S10')],
#  [1809, array(['a', 'crowd', 'dances', 'while', 'a', 'rock', 'band', 'plays'],
#         dtype='|S6')],
#  [1447, array(['a', 'woman', 'gallops', 'on', 'a', 'horse'], dtype='|S7')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'rode', 'a', 'horse', 'in', 'the', 'barn'],
#         dtype='|S5')],
#  [1447, array(['a', 'lady', 'is', 'riding', 'a', 'horse', 'in', 'a', 'barn'],
#         dtype='|S6')],
#  [1447, array(['a', 'person', 'is', 'keeping', 'their', 'horse', 'at', 'a',
#          'trot'], dtype='|S7')],
#  [1447, array(['a', 'person', 'is', 'riding', 'a', 'horse', 'along', 'the',
#          'perimeter'], dtype='|S9')],
#  [1447, array(['a', 'woman', 'is', 'galloping', 'a', 'horse', 'around', 'an',
#          'inside', 'arena'], dtype='|S9')],
#  [1447,
#   array(['a', 'woman', 'is', 'riding', 'a', 'horse', 'in', 'an', 'enlosed',
#          'covered', 'area'], dtype='|S7')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'woman', 'is', 'riding', 'on', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'woman', 'is', 'riding', 'on', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['the', 'horse', 'and', 'rider', 'trotted', 'around', 'the', 'barn'],
#         dtype='|S7')],
#  [1447, array(['the', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'girl', 'is', 'riding', 'in', 'the', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'sitting', 'on', 'the', 'black', 'horse'],
#         dtype='|S7')],
#  [1447, array(['a', 'lady', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'man', 'is', 'rading', 'in', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'men', 'walking', 'on', 'house'], dtype='|S7')],
#  [1447, array(['a', 'person', 'is', 'riding', 'on', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['few', 'guys', 'are', 'driving', 'the', 'horses'], dtype='|S7')],
#  [1447, array(['fiona', 'my', 'best', 'friend'], dtype='|S6')],
#  [1447, array(['one', 'lady', 'riding', 'on', 'horse'], dtype='|S6')],
#  [1447, array(['someone', 'is', 'riding', 'a', 'horse'], dtype='|S7')],
#  [1447, array(['the', 'man', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'boy', 'riding', 'a', 'horse', 'in', 'horse', 'stable'],
#         dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'girl', 'is', 'riding', 'a', 'horse', 'inside', 'a', 'barn'],
#         dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'girl', 'riding', 'with', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'horse', 'is', 'driven', 'by', 'a', 'woman'], dtype='|S6')],
#  [1447, array(['a', 'lady', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'man', 'is', 'jogging', 'on', 'the', 'horse'], dtype='|S7')],
#  [1447, array(['a', 'man', 'is', 'riding', 'on', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'man', 'is', 'riding', 'on', 'the', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'man', 'rides', 'a', 'horse', 'in', 'the', 'barn'],
#         dtype='|S5')],
#  [1447, array(['a', 'man', 'riding', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'person', 'is', 'riding', 'a', 'horse', 'inside', 'a',
#          'large', 'building'], dtype='|S8')],
#  [1447, array(['a', 'person', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'person', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447,
#   array(['a', 'person', 'rides', 'a', 'horse', 'in', 'stable'], dtype='|S6')],
#  [1447,
#   array(['a', 'woman', 'is', 'riding', 'a', 'horse', 'beside', 'a', 'wall'],
#         dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse', 'in', 'a', 'barn'],
#         dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'is', 'riding', 'around', 'on', 'a', 'horse'],
#         dtype='|S6')],
#  [1447,
#   array(['a', 'woman', 'is', 'riding', 'on', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'woman', 'rides', 'a', 'horse', 'inside', 'a', 'barn'],
#         dtype='|S6')],
#  [1447,
#   array(['the', 'person', 'is', 'raiding', 'the', 'horse'], dtype='|S7')],
#  [1447, array(['a', 'man', 'is', 'riding', 'in', 'a', 'horse'], dtype='|S6')],
#  [1447, array(['a', 'man', 'practice', 'horse', 'riding'], dtype='|S8')],
#  [1447,
#   array(['a', 'young', 'girl', 'is', 'riding', 'a', 'horse'], dtype='|S6')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'cell', 'phone'],
#         dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'mobile', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'speaking', 'on', 'a', 'telephone'], dtype='|S9')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'telephone'], dtype='|S9')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'cell', 'phone'],
#         dtype='|S7')],
#  [1867, array(['a', 'man', 'talks', 'on', 'a', 'telephone'], dtype='|S9')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'speaks', 'on', 'a', 'cell', 'phone'], dtype='|S6')],
#  [1867,
#   array(['the', 'man', 'talked', 'on', 'the', 'telephone'], dtype='|S9')],
#  [1867,
#   array(['the', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'talks', 'on', 'the', 'phone'], dtype='|S5')],
#  [1867, array(['a', 'mand', 'talked', 'on', 'the', 'phone'], dtype='|S6')],
#  [1867, array(['the', 'man', 'is', 'very', 'happy', 'to', 'speak', 'in', 'the',
#          'cell', 'phone'], dtype='|S5')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'person', 'taking', 'on', 'phone'], dtype='|S6')],
#  [1867, array(['three', 'boys', 'is', 'talk', 'in', 'office'], dtype='|S6')],
#  [1867, array(['a', 'men', 'is', 'talking', 'in', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'on', 'conversation', 'on', 'phone'],
#         dtype='|S12')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'a', 'mobile'], dtype='|S7')],
#  [1867, array(['a', 'lone', 'man', 'in', 'a', 'white', 'shirt', 'and', 'brown',
#          'tie', 'looking', 'unhappy'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'in', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'stands', 'up', 'and', 'talks', 'on', 'his',
#          'cellphone'], dtype='|S9')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'his', 'cell', 'phone'],
#         dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['someone', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'talking', 'in', 'his', 'mobile', 'phone'],
#         dtype='|S7')],
#  [1867, array(['a', 'man', 'talking', 'to', 'someone', 'on', 'telephone'],
#         dtype='|S9')],
#  [1867, array(['a', 'man', 'is', 'chatting', 'on', 'phone'], dtype='|S8')],
#  [1867, array(['a', 'man', 'is', 'talking', 'on', 'a', 'cordless', 'phone'],
#         dtype='|S8')],
#  [1867,
#   array(['the', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['a', 'man', 'is', 'speaking', 'on', 'a', 'phone'], dtype='|S8')],
#  [1867,
#   array(['a', 'man', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'talks', 'on', 'the', 'phone'], dtype='|S5')],
#  [1867, array(['he', 'is', 'talking', 'on', 'the', 'phone'], dtype='|S7')],
#  [1867,
#   array(['the', 'person', 'is', 'talking', 'with', 'phone'], dtype='|S7')],
#  [1867, array(['a', 'man', 'is', 'speaking', 'phone'], dtype='|S8')],
#  [1867, array(['a', 'man', 'is', 'talking', 'in', 'phone'], dtype='|S7')],
#  [1870,
#   array(['a', 'group', 'of', 'boys', 'are', 'jumping', 'into', 'a', 'river'],
#         dtype='|S7')],
#  [1870,
#   array(['a', 'group', 'of', 'people', 'are', 'jumping', 'into', 'water'],
#         dtype='|S7')],
#  [1870, array(['men', 'are', 'diving', 'into', 'the', 'river'], dtype='|S6')],
#  [1870,
#   array(['men', 'are', 'jumping', 'into', 'water', 'from', 'a', 'bridge'],
#         dtype='|S7')],
#  [1870, array(['men', 'are', 'swimming'], dtype='|S8')],
#  [1870, array(['men', 'jump', 'in', 'a', 'river'], dtype='|S5')],
#  [1870, array(['people', 'are', 'jumping', 'in', 'a', 'river'], dtype='|S7')],
#  [1870,
#   array(['people', 'are', 'jumping', 'off', 'a', 'bridge', 'into', 'water'],
#         dtype='|S7')],
#  [1870,
#   array(['several', 'men', 'are', 'jumping', 'off', 'a', 'bridge', 'into',
#          'a', 'creek'], dtype='|S7')],
#  [1870, array(['several', 'men', 'jump', 'off', 'a', 'small', 'bridge', 'into',
#          'a', 'pool', 'of', 'water'], dtype='|S7')],
#  [1870, array(['several', 'people', 'play', 'in', 'a', 'river'], dtype='|S7')],
#  [1870, array(['some', 'young', 'men', 'dive', 'and', 'jump', 'into', 'the',
#          'water'], dtype='|S5')],
#  [1870, array(['the', 'men', 'dived', 'into', 'the', 'water', 'from', 'the',
#          'bridge'], dtype='|S6')],
#  [1870, array(['the', 'men', 'jumped', 'into', 'the', 'river'], dtype='|S6')],
#  [1870, array(['the', 'people', 'dived', 'off', 'the', 'rock', 'bridge'],
#         dtype='|S6')],
#  [1870, array(['three', 'men', 'jump', 'off', 'of', 'a', 'small', 'bridge'],
#         dtype='|S6')],
#  [1870, array(['two', 'men', 'dive', 'into', 'the', 'water', 'where', 'two',
#          'others', 'are', 'already', 'swimming'], dtype='|S8')],
#  [1870, array(['men', 'are', 'diving', 'in', 'the', 'river'], dtype='|S6')],
#  [1870,
#   array(['they', 'are', 'jumping', 'into', 'the', 'river'], dtype='|S7')],
#  [1870,
#   array(['the', 'boys', 'are', 'jumping', 'in', 'to', 'lake'], dtype='|S7')],
#  [1870, array(['men', 'jump', 'into', 'a', 'river'], dtype='|S5')],
#  [1870, array(['boys', 'are', 'playing', 'in', 'the', 'water'], dtype='|S7')],
#  [1870,
#   array(['a', 'man', 'is', 'jumping', 'on', 'the', 'water'], dtype='|S7')],
#  [1870,
#   array(['3', 'persons', 'diving', 'in', 'to', 'the', 'river'], dtype='|S7')],
#  [1870,
#   array(['people', 'were', 'jumping', 'into', 'the', 'water'], dtype='|S7')],
#  [1870,
#   array(['people', 'are', 'jumping', 'into', 'the', 'water'], dtype='|S7')],
#  [1870,
#   array(['all', 'people', 'are', 'jumping', 'into', 'water'], dtype='|S7')],
#  [1870, array(['people', 'dive', 'into', 'the', 'water'], dtype='|S6')],
#  [1870, array(['some', 'men', 'are', 'diving', 'into', 'water'], dtype='|S6')],
#  [1870,
#   array(['a', 'group', 'of', 'men', 'are', 'diving', 'into', 'a', 'lake'],
#         dtype='|S6')],
#  [1870, array(['men', 'are', 'diving', 'into', 'water'], dtype='|S6')],
#  [1870,
#   array(['a', 'group', 'of', 'men', 'jumping', 'into', 'water'], dtype='|S7')],
#  [1870, array(['some', 'people', 'taking', 'bath'], dtype='|S6')],
#  [1870, array(['men', 'are', 'diving', 'in', 'the', 'water'], dtype='|S6')],
#  [1870,
#   array(['he', 'is', 'jumping', 'in', 'water', 'very', 'well'], dtype='|S7')],
#  [1870, array(['people', 'jump', 'into', 'a', 'creek'], dtype='|S6')],
#  [1731, array(['a', 'man', 'is', 'arranging', 'sushi'], dtype='|S9')],
#  [1731, array(['a', 'person', 'is', 'arranging', 'food', 'on', 'a', 'dish'],
#         dtype='|S9')],
#  [1731,
#   array(['a', 'person', 'is', 'making', 'a', 'hot', 'dog', 'piece', 'look',
#          'like', 'an', 'octopus'], dtype='|S7')],
#  [1731, array(['a', 'woman', 'arranges', 'a', 'food', 'dish'], dtype='|S8')],
#  [1731, array(['a', 'woman', 'cuts', 'a', 'squid'], dtype='|S5')],
#  [1731, array(['a', 'woman', 'is', 'adding', 'eyes', 'to', 'squash', 'cut',
#          'into', 'ghostlike', 'pieces'], dtype='|S9')],
#  [1731, array(['a', 'woman', 'is', 'arranging', 'some', 'food', 'and',
#          'decorating', 'it'], dtype='|S10')],
#  [1731,
#   array(['a', 'woman', 'is', 'decorating', 'some', 'food'], dtype='|S10')],
#  [1731, array(['a', 'woman', 'is', 'preparing', 'a', 'plate', 'of', 'food'],
#         dtype='|S9')],
#  [1731, array(['a', 'woman', 'is', 'preparing', 'food'], dtype='|S9')],
#  [1731, array(['a', 'woman', 'places', 'sesame', 'seeds', 'as', 'eyes', 'on',
#          'an', 'octopusshaped', 'sausage', 'placed', 'on', 'a', 'small',
#          'white', 'tray'], dtype='|S13')],
#  [1731, array(['a', 'woman', 'prepares', 'a', 'sushi', 'tray'], dtype='|S8')],
#  [1731, array(['sesame', 'seed', 'eyes', 'are', 'added', 'to', 'a', 'sausage',
#          'cut', 'to', 'look', 'like', 'an', 'octopus'], dtype='|S7')],
#  [1731, array(['someone', 'is', 'decorating', 'a', 'cut', 'piece', 'of',
#          'sausage', 'with', 'eyes'], dtype='|S10')],
#  [1731, array(['someone', 'is', 'decorating', 'food', 'on', 'a', 'plate'],
#         dtype='|S10')],
#  [1731,
#   array(['someone', 'made', 'the', 'sushi', 'look', 'like', 'an', 'octopus'],
#         dtype='|S7')],
#  [1731, array(['the', 'lady', 'made', 'the', 'sushi', 'look', 'like', 'an',
#          'octopus'], dtype='|S7')],
#  [1731,
#   array(['the', 'woman', 'is', 'garnishing', 'vegetables'], dtype='|S10')],
#  [1731, array(['a', 'woman', 'garnish', 'a', 'bento', 'dish', 'in', 'the',
#          'serving', 'plate'], dtype='|S7')],
#  [1731, array(['a', 'woman', 'is', 'putting', 'a', 'vegetable', 'on', 'a',
#          'plate'], dtype='|S9')],
#  [1731, array(['the', 'person', 'is', 'showing', 'how', 'to', 'make', 'bento'],
#         dtype='|S7')],
#  [1731, array(['a', 'woman', 'prepares', 'a', 'bento', 'box'], dtype='|S8')],
#  [1731, array(['a', 'person', 'puts', 'seeds', 'on', 'a', 'hot', 'dog'],
#         dtype='|S6')],
#  [1731, array(['a', 'person', 'is', 'placing', 'the', 'black', 'thing', 'on',
#          'the', 'food'], dtype='|S7')],
#  [1731, array(['a', 'lady', 'is', 'decorating', 'her', 'dish'], dtype='|S10')],
#  [1731, array(['someone', 'put', 'two', 'sausages', 'on', 'a', 'platter'],
#         dtype='|S8')],
#  [1731, array(['someone', 'is', 'preparing', 'some', 'food'], dtype='|S9')],
#  [1731,
#   array(['a', 'woman', 'is', 'preparing', 'some', 'bento'], dtype='|S9')],
#  [1731, array(['a', 'man', 'coking'], dtype='|S6')],
#  [1731, array(['somebody', 'is', 'decorating', 'vegetables'], dtype='|S10')],
#  [1731,
#   array(['a', 'video', 'on', 'how', 'to', 'make', 'bento'], dtype='|S5')],
#  [1731, array(['a', 'person', 'making', 'bento'], dtype='|S6')],
#  [1731, array(['a', 'woman', 'plates', 'an', 'asian', 'dish'], dtype='|S6')],
#  [1731, array(['a', 'person', 'making', 'bento'], dtype='|S6')],
#  [1731, array(['a', 'woman', 'adds', 'eyes', 'to', 'a', 'piece', 'of', 'food',
#          'to', 'make', 'it', 'look', 'like', 'an', 'octopus'], dtype='|S7')],
#  [1731,
#   array(['a', 'plate', 'with', 'full', 'of', 'fruits', 'are', 'displayed'],
#         dtype='|S9')],
#  [1731,
#   array(['the', 'woman', 'is', 'garnishing', 'the', 'plate'], dtype='|S10')],
#  [1731, array(['how', 'to', 'make', 'bento', 'japanese', 'boxed', 'lunch'],
#         dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'person', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334,
#   array(['someone', 'is', 'kneading', 'a', 'large', 'piece', 'of', 'dough'],
#         dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'a', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'lwoman', 'is', 'preparing', 'something'], dtype='|S9')],
#  [1334,
#   array(['a', 'woman', 'is', 'kneading', 'dough', 'with', 'her', 'hands'],
#         dtype='|S8')],
#  [1334, array(['a', 'person', 'is', 'mashing', 'dough'], dtype='|S7')],
#  [1334, array(['a', 'person', 'kneads', 'dough', 'with', 'their', 'hands'],
#         dtype='|S6')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneeding', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'some', 'dough'], dtype='|S8')],
#  [1334, array(['the', 'lady', 'rolled', 'out', 'the', 'dough'], dtype='|S6')],
#  [1334, array(['the', 'baker', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'marzipan'], dtype='|S8')],
#  [1334, array(['a', 'chef', 'kneads', 'dough'], dtype='|S6')],
#  [1334, array(['the', 'lady', 'rolled', 'the', 'dough'], dtype='|S6')],
#  [1334, array(['one', 'person', 'is', 'cooking'], dtype='|S7')],
#  [1334, array(['the', 'person', 'is', 'cooking'], dtype='|S7')],
#  [1334,
#   array(['a', 'woman', 'in', 'a', 'white', 'top', 'holding', 'a', 'cake'],
#         dtype='|S7')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'person', 'is', 'making', 'cake'], dtype='|S6')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'girl', 'is', 'making', 'a', 'aatta'], dtype='|S6')],
#  [1334, array(['a', 'woman', 'is', 'kneeding', 'some', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'man', 'is', 'mixing', 'meal'], dtype='|S6')],
#  [1334, array(['a', 'man', 'coking', 'cake'], dtype='|S6')],
#  [1334, array(['someone', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'person', 'is', 'preparing', 'for', 'cake'], dtype='|S9')],
#  [1334, array(['one', 'man', 'rooling', 'bread', 'with', 'pastry', 'roller'],
#         dtype='|S7')],
#  [1334, array(['a', 'woman', 'showing', 'cake'], dtype='|S7')],
#  [1334, array(['the', 'man', 'is', 'kneading', 'dough'], dtype='|S8')],
#  [1334, array(['how', 'to', 'make', 'a', 'wedding', 'cake'], dtype='|S7')],
#  [1334, array(['a', 'women', 'is', 'made', 'cake'], dtype='|S5')],
#  [1334, array(['icing', 'a', 'wedding', 'cake', 'video'], dtype='|S7')],
#  [1334, array(['a', 'woman', 'is', 'pressing', 'dough'], dtype='|S8')],
#  [1334, array(['a', 'woman', 'is', 'kneading', 'marzipan'], dtype='|S8')],
#  [1334, array(['a', 'chef', 'kneads', 'dough'], dtype='|S6')],
#  [1691, array(['a', 'person', 'is', 'feeding', 'two', 'baby', 'pandas'],
#         dtype='|S7')],
#  [1691, array(['a', 'lady', 'is', 'giving', 'two', 'baby', 'pandas', 'milk',
#          'bottles'], dtype='|S7')],
#  [1691, array(['a', 'man', 'is', 'drinking', 'bottlesmilk', 'to', 'pandas'],
#         dtype='|S11')],
#  [1691,
#   array(['a', 'person', 'feeds', 'baby', 'pandas', 'with', 'a', 'bottle'],
#         dtype='|S6')],
#  [1691, array(['a', 'man', 'is', 'giving', 'milk', 'bottles', 'to', 'panda',
#          'babies'], dtype='|S7')],
#  [1691,
#   array(['a', 'person', 'is', 'giving', 'baby', 'pandas', 'bottles', 'of',
#          'milk'], dtype='|S7')],
#  [1691, array(['a', 'person', 'is', 'giving', 'bottles', 'of', 'milk', 'to',
#          'baby', 'pandas'], dtype='|S7')],
#  [1691,
#   array(['a', 'person', 'gives', 'two', 'panda', 'bears', 'bottles', 'of',
#          'milk'], dtype='|S7')],
#  [1691,
#   array(['a', 'man', 'is', 'feeding', 'a', 'baby', 'panda'], dtype='|S7')],
#  [1691, array(['panda', 'bears', 'are', 'eating'], dtype='|S6')],
#  [1691,
#   array(['two', 'pandas', 'are', 'drinking', 'milk', 'from', 'a', 'bottle'],
#         dtype='|S8')],
#  [1691, array(['a', 'man', 'gives', 'milk', 'in', 'individual', 'feeding',
#          'bottles', 'to', 'two', 'pandas', 'in', 'a', 'cage'], dtype='|S10')],
#  [1691,
#   array(['the', 'keeper', 'fed', 'bottles', 'to', 'the', 'two', 'pandas'],
#         dtype='|S7')],
#  [1691,
#   array(['the', 'pandas', 'are', 'being', 'fed', 'with', 'baby', 'bottles'],
#         dtype='|S7')],
#  [1691, array(['a', 'man', 'feeds', 'some', 'baby', 'pandas'], dtype='|S6')],
#  [1691,
#   array(['the', 'veterinarian', 'fed', 'the', 'pandas', 'their', 'bottles'],
#         dtype='|S12')],
#  [1691, array(['a', 'person', 'is', 'give', 'milk', 'to', 'baby', 'panda'],
#         dtype='|S6')],
#  [1691,
#   array(['the', 'person', 'is', 'doing', 'the', 'somthing'], dtype='|S8')],
#  [1691, array(['a', 'person', 'is', 'feeding', 'two', 'pandas'], dtype='|S7')],
#  [1691,
#   array(['two', 'baby', 'pandas', 'being', 'fed', 'milk', 'in', 'a', 'cage'],
#         dtype='|S6')],
#  [1691, array(['a', 'person', 'is', 'bottle', 'feeding', 'a', 'panda'],
#         dtype='|S7')],
#  [1691, array(['the', 'person', 'is', 'giving', 'milk', 'to', 'panda'],
#         dtype='|S6')],
#  [1691, array(['baby', 'panda', 'drinking', 'milk'], dtype='|S8')],
#  [1691, array(['a', 'woman', 'is', 'feeding', 'two', 'pandas'], dtype='|S7')],
#  [1691, array(['two', 'pandas', 'are', 'drinking', 'milk'], dtype='|S8')],
#  [1691, array(['two', 'baby', 'pandas', 'are', 'getting', 'milk', 'bottles'],
#         dtype='|S7')],
#  [1691, array(['a', 'man', 'is', 'giving', 'milk', 'to', 'two', 'pandas', 'in',
#          'a', 'feeding', 'bottle'], dtype='|S7')],
# ...
#  [1748, array(['a', 'flock', 'of', 'zebras', 'grazing'], dtype='|S7')],
#  [1748, array(['a', 'group', 'of', 'zebra', 'are', 'grazing'], dtype='|S7')],
#  [1748,
#   array(['a', 'herd', 'of', 'zebras', 'are', 'standing', 'in', 'a', 'field'],
#         dtype='|S8')],
#  [1748, array(['a', 'herd', 'of', 'zebras', 'graze', 'in', 'the', 'savannah'],
#         dtype='|S8')],
#  [1748,
#   array(['a', 'herd', 'of', 'zebras', 'stand', 'on', 'a', 'grassy', 'plain'],
#         dtype='|S6')],
#  [1748, array(['a', 'pack', 'of', 'zebras', 'are', 'grazing'], dtype='|S7')],
#  [1748, array(['many', 'zebras', 'are', 'grazing', 'in', 'a', 'field'],
#         dtype='|S7')],
#  [1748, array(['many', 'zebras', 'graze', 'in', 'a', 'field'], dtype='|S6')],
#  [1748, array(['several', 'zebras', 'are', 'standing', 'in', 'a', 'field'],
#         dtype='|S8')],
#  [1748, array(['the', 'zebras', 'are', 'grazing'], dtype='|S7')],
#  [1748, array(['the', 'zebras', 'grazed', 'in', 'the', 'field'], dtype='|S6')],
#  [1748,
#   array(['the', 'zebras', 'grazed', 'on', 'the', 'grasses'], dtype='|S7')],
#  [1748, array(['zebra', 'are', 'eating', 'grass'], dtype='|S6')],
#  [1748, array(['zebras', 'are', 'eating', 'grass'], dtype='|S6')],
#  [1748, array(['zebras', 'are', 'grassing'], dtype='|S8')],
#  [1748,
#   array(['zebras', 'are', 'grazing', 'in', 'the', 'grass'], dtype='|S7')],
#  [1748, array(['zebras', 'are', 'standing', 'peacefully'], dtype='|S10')],
#  [1748, array(['zebras', 'are', 'eating'], dtype='|S6')],
#  [1748, array(['zebras', 'are', 'eating', 'grass'], dtype='|S6')],
#  [1748,
#   array(['a', 'herd', 'of', 'zebras', 'are', 'eating', 'grass', 'in', 'a',
#          'field'], dtype='|S6')],
#  [1748, array(['zebras', 'are', 'standing', 'in', 'a', 'field'], dtype='|S8')],
#  [1748, array(['zebras', 'are', 'grazing', 'in', 'a', 'field'], dtype='|S7')],
#  [1748,
#   array(['zebras', 'are', 'grazing', 'in', 'the', 'field'], dtype='|S7')],
#  [1748, array(['zebras', 'gracing', 'on', 'grassland'], dtype='|S9')],
#  [1748, array(['the', 'zebras', 'are', 'grazing'], dtype='|S7')],
#  [1748,
#   array(['zebras', 'are', 'standing', 'in', 'a', 'jungle'], dtype='|S8')],
#  [1748, array(['many', 'zebras', 'are', 'standing', 'in', 'a', 'field'],
#         dtype='|S8')],
#  [1748, array(['zebras', 'were', 'found', 'in', 'a', 'group'], dtype='|S6')],
#  [1748,
#   array(['zebras', 'are', 'standing', 'and', 'eating', 'grass'], dtype='|S8')],
#  [1748, array(['zebras', 'are', 'standing', 'in', 'a', 'field'], dtype='|S8')],
#  [1748, array(['eating', 'together'], dtype='|S8')],
#  [1748,
#   array(['lots', 'of', 'zebras', 'are', 'eating', 'grass'], dtype='|S6')],
#  [1748, array(['some', 'zebras', 'are', 'standing', 'in', 'a', 'field'],
#         dtype='|S8')],
#  [1748, array(['a', 'herd', 'of', 'zebras', 'are', 'grazing'], dtype='|S7')],
#  [1748, array(['all', 'zebras', 'are', 'in', 'forest'], dtype='|S6')],
#  [1748, array(['zebras', 'are', 'eating'], dtype='|S6')],
#  [1748, array(['some', 'zebras', 'are', 'walking', 'in', 'a', 'field'],
#         dtype='|S7')],
#  [1748, array(['the', 'zebras', 'grazed', 'on', 'the', 'grass'], dtype='|S6')],
#  [1748, array(['zebras', 'having', 'they', 'food'], dtype='|S6')],
#  [1748, array(['a', 'running', 'zebras'], dtype='|S7')],
#  [1748, array(['zebras', 'graze', 'in', 'the', 'savanna'], dtype='|S7')],
#  [1748, array(['the', 'zebras', 'are', 'gazing', 'in', 'the', 'fields'],
#         dtype='|S6')],
#  [1748,
#   array(['a', 'group', 'of', 'zebras', 'are', 'grazing', 'in', 'a', 'field'],
#         dtype='|S7')],
#  [1748, array(['very', 'cute', 'zebras'], dtype='|S6')],
#  [1748, array(['a', 'group', 'of', 'zebras', 'are', 'standing', 'in', 'a',
#          'field'], dtype='|S8')],
#  [1419, array(['a', 'lion', 'jumps', 'and', 'hangs', 'off', 'the', 'top', 'of',
#          'a', 'fence', 'in', 'an', 'enclosed', 'area'], dtype='|S8')],
#  [1419, array(['a', 'lion', 'jumps', 'on', 'a', 'fence'], dtype='|S5')],
#  [1419, array(['a', 'lion', 'jumps', 'on', 'a', 'fence'], dtype='|S5')],
#  [1419,
#   array(['a', 'lion', 'is', 'trying', 'to', 'climb', 'over', 'a', 'wall'],
#         dtype='|S6')],
#  [1419,
#   array(['a', 'tiger', 'cub', 'is', 'trying', 'to', 'climb', 'a', 'wall'],
#         dtype='|S6')],
#  [1419, array(['a', 'lion', 'is', 'trying', 'to', 'climb', 'up', 'over', 'a',
#          'wall'], dtype='|S6')],
#  [1419,
#   array(['a', 'lion', 'is', 'jumping', 'over', 'a', 'fence'], dtype='|S7')],
#  [1419, array(['a', 'baby', 'lion', 'is', 'trying', 'to', 'climb', 'out', 'of',
#          'its', 'pen'], dtype='|S6')],
#  [1419, array(['a', 'lioness', 'is', 'hanging', 'on', 'to', 'a', 'ledge'],
#         dtype='|S7')],
#  [1419, array(['a', 'lion', 'tries', 'to', 'climb', 'over', 'a', 'wall'],
#         dtype='|S5')],
#  [1419, array(['a', 'lion', 'is', 'climbing', 'a', 'fence'], dtype='|S8')],
#  [1419, array(['a', 'lion', 'cub', 'tries', 'to', 'climb', 'a', 'fence'],
#         dtype='|S5')],
#  [1419, array(['the', 'lion', 'cub', 'is', 'trying', 'to', 'climb', 'the',
#          'fence'], dtype='|S6')],
#  [1419, array(['a', 'lioness', 'is', 'jumping', 'up', 'the', 'wall', 'trying',
#          'to', 'get', 'out', 'of', 'a', 'pen'], dtype='|S7')],
#  [1419, array(['a', 'cat', 'climbs', 'up', 'a', 'fence'], dtype='|S6')],
#  [1419,
#   array(['a', 'tiger', 'trys', 'to', 'climb', 'the', 'wall'], dtype='|S5')],
#  [1419,
#   array(['a', 'lion', 'is', 'jumping', 'on', 'a', 'fence'], dtype='|S7')],
#  [1419,
#   array(['the', 'tiger', 'tried', 'to', 'jump', 'out', 'of', 'his', 'pen'],
#         dtype='|S5')],
#  [1419, array(['the', 'lion', 'is', 'jumping'], dtype='|S7')],
#  [1419, array(['a', 'lion', 'is', 'jumping', 'and', 'hanging', 'onto', 'a',
#          'wall', 'before', 'he', 'falls'], dtype='|S7')],
#  [1419, array(['a', 'cub', 'is', 'jumping'], dtype='|S7')],
#  [1419, array(['a', 'lion', 'is', 'climbing', 'a', 'fence'], dtype='|S8')],
#  [1419,
#   array(['at', 'the', 'zoo', 'where', 'a', 'small', 'lion', 'cub', 'tries',
#          'to', 'climb', 'the', 'fence'], dtype='|S5')],
#  [1419, array(['the', 'loin', 'is', 'trying', 'the', 'jumping'], dtype='|S7')],
#  [1419, array(['a', 'lion', 'cub', 'tries', 'to', 'jump', 'a', 'fence'],
#         dtype='|S5')],
#  [1419, array(['one', 'tiger', 'is', 'astap', 'by', 'stap', 'of', 'grill'],
#         dtype='|S5')],
#  [1419,
#   array(['a', 'tiger', 'club', 'trying', 'to', 'climb', 'on', 'a', 'wall',
#          'inorder', 'to', 'cross', 'it'], dtype='|S7')],
#  [1419,
#   array(['the', 'lion', 'tried', 'to', 'jump', 'out', 'of', 'its', 'pen'],
#         dtype='|S5')],
#  [1419, array(['a', 'cat', 'is', 'playing'], dtype='|S7')],
#  [1419,
#   array(['the', 'dog', 'is', 'trying', 'to', 'get', 'over', 'the', 'fence'],
#         dtype='|S6')],
#  [1419,
#   array(['a', 'tiger', 'is', 'climbing', 'on', 'a', 'fence'], dtype='|S8')],
#  [1616, array(['someone', 'is', 'cutting', 'a', 'cooked', 'potato', 'into',
#          'bitesize', 'pieces'], dtype='|S8')],
#  [1616, array(['a', 'person', 'is', 'slicing', 'a', 'potato'], dtype='|S7')],
#  [1616, array(['a', 'person', 'is', 'slicing', 'potatoes'], dtype='|S8')],
#  [1616, array(['a', 'man', 'is', 'cutting', 'a', 'potato', 'into', 'eighths'],
#         dtype='|S7')],
#  [1616,
#   array(['a', 'person', 'is', 'slicing', 'a', 'potato', 'into', 'pieces'],
#         dtype='|S7')],
#  [1616, array(['a', 'person', 'is', 'cutting', 'potatoes', 'into', 'wedges'],
#         dtype='|S8')],
#  [1616, array(['a', 'man', 'is', 'slicing', 'potato'], dtype='|S7')],
#  [1616, array(['a', 'man', 'i', 'chopping', 'up', 'potatoes'], dtype='|S8')],
#  [1616, array(['a', 'person', 'slices', 'a', 'potato', 'into', 'wedges'],
#         dtype='|S6')],
#  [1616,
#   array(['a', 'man', 'is', 'cutting', 'up', 'a', 'potato'], dtype='|S7')],
#  [1616, array(['a', 'man', 'is', 'cutting', 'a', 'potato'], dtype='|S7')],
#  [1616, array(['a', 'person', 'is', 'slicing', 'a', 'potato'], dtype='|S7')],
#  [1616, array(['the', 'man', 'is', 'slicing', 'potatoes'], dtype='|S8')],
#  [1616, array(['a', 'man', 'is', 'cutting', 'a', 'boiled', 'potato', 'into',
#          'small', 'pieces'], dtype='|S7')],
#  [1616, array(['a', 'man', 'cuts', 'potatos'], dtype='|S7')],
#  [1616, array(['the', 'man', 'cut', 'the', 'potatoe', 'into', 'pieces'],
#         dtype='|S7')],
#  [1616, array(['the', 'person', 'is', 'ready', 'to', 'the', 'potato', 'salad'],
#         dtype='|S6')],
#  [1616, array(['a', 'man', 'is', 'cutting', 'the', 'potatoes'], dtype='|S8')],
#  [1616, array(['a', 'women', 'cutting', 'the', 'potatoes'], dtype='|S8')],
#  [1616, array(['someone', 'is', 'cutting', 'a', 'potatoe'], dtype='|S7')],
#  [1616, array(['slicing', 'a', 'potato', 'into', 'quarters', 'and', 'then',
#          'fourths'], dtype='|S8')],
#  [1616, array(['a', 'person', 'coking'], dtype='|S6')],
#  [1616, array(['a', 'person', 'is', 'slicing', 'a', 'potato'], dtype='|S7')],
#  [1616, array(['a', 'chinese', 'lady', 'preparing', 'some', 'sort', 'of',
#          'potato', 'salad'], dtype='|S9')],
#  [1616,
#   array(['the', 'lady', 'cut', 'the', 'potatoe', 'into', 'small', 'pieces'],
#         dtype='|S7')],
#  [1616, array(['a', 'man', 'cooking', 'his', 'kichen'], dtype='|S7')],
#  [1616, array(['a', 'man', 'is', 'cutting', 'a', 'potato', 'into', 'large',
#          'pieces'], dtype='|S7')],
#  [1616, array(['the', 'cook', 'is', 'cutting', 'potatos'], dtype='|S7')],
#  [1965,
#   array(['a', 'boy', 'does', 'flips', 'on', 'a', 'trampoline'], dtype='|S10')],
#  [1965, array(['a', 'boy', 'is', 'doing', 'flips', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['a', 'boy', 'is', 'flipping', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['a', 'guy', 'is', 'flipping', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['a', 'man', 'is', 'doing', 'back', 'flips', 'on', 'a',
#          'trampoline'], dtype='|S10')],
#  [1965,
#   array(['different', 'children', 'jump', 'on', 'different', 'trampolines'],
#         dtype='|S11')],
#  [1965, array(['kids', 'are', 'doing', 'tricks', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965,
#   array(['kids', 'doing', 'flips', 'on', 'a', 'trampoline'], dtype='|S10')],
#  [1965,
#   array(['people', 'are', 'jumping', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['people', 'do', 'flips', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['people', 'jump', 'on', 'a', 'trampoline'], dtype='|S10')],
#  [1965,
#   array(['peoples', 'are', 'jumping', 'on', 'a', 'trampoline'], dtype='|S10')],
#  [1965, array(['several', 'groups', 'of', 'children', 'are', 'shown', 'doing',
#          'flips', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['several', 'kids', 'are', 'doing', 'tricks', 'on', 'a',
#          'trampoline'], dtype='|S10')],
#  [1965, array(['several', 'kids', 'jump', 'up', 'and', 'down', 'on', 'a',
#          'trampoline'], dtype='|S10')],
#  [1965, array(['some', 'children', 'are', 'jumping', 'on', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['the', 'boys', 'did', 'tricks', 'on', 'the', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['the', 'kids', 'are', 'playing', 'on', 'the', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['the', 'two', 'boys', 'jumped', 'on', 'the', 'tramplines'],
#         dtype='|S10')],
#  [1965, array(['two', 'boy', 'are', 'playing', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965,
#   array(['two', 'kids', 'are', 'doing', 'tricks', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965,
#   array(['two', 'men', 'are', 'jumping', 'and', 'one', 'of', 'them', 'does',
#          'summersaults', 'on', 'a', 'bouncy', 'trampoline', 'sheet'],
#         dtype='|S12')],
#  [1965, array(['boys', 'jumping', 'on', 'trampoline'], dtype='|S10')],
#  [1965,
#   array(['a', 'kids', 'are', 'jumping', 'in', 'the', 'net'], dtype='|S7')],
#  [1965, array(['the', 'person', 'is', 'jumping'], dtype='|S7')],
#  [1965,
#   array(['people', 'are', 'jumping', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['people', 'are', 'doing', 'flips', 'on', 'trampolines'],
#         dtype='|S11')],
#  [1965, array(['the', 'boys', 'are', 'trampoline', 'tricks'], dtype='|S10')],
#  [1965, array(['people', 'jump', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['a', 'boy', 'is', 'somersaulting', 'on', 'the', 'net'],
#         dtype='|S13')],
#  [1965, array(['two', 'guys', 'showing', 'some', 'trampoline', 'tricks'],
#         dtype='|S10')],
#  [1965,
#   array(['two', 'men', 'were', 'doing', 'amazing', 'things'], dtype='|S7')],
#  [1965, array(['people', 'are', 'doing', 'flips', 'and', 'tricks', 'on',
#          'trampolines'], dtype='|S11')],
#  [1965, array(['a', 'two', 'boys', 'are', 'playing', 'on', 'the', 'bed'],
#         dtype='|S7')],
#  [1965, array(['kids', 'doing', 'flips', 'on', 'trampolines'], dtype='|S11')],
#  [1965, array(['veri', 'nice'], dtype='|S4')],
#  [1965, array(['a', 'boy', 'is', 'doing', 'flips', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['a', 'boyes', 'can', 'be', 'jumping'], dtype='|S7')],
#  [1965, array(['two', 'kids', 'are', 'playing', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['a', 'boy', 'is', 'jumping'], dtype='|S7')],
#  [1965, array(['two', 'boys', 'on', 'a', 'trampoline'], dtype='|S10')],
#  [1965, array(['a', 'bunch', 'of', 'young', 'boys', 'do', 'tricks', 'on', 'a',
#          'tranpoline'], dtype='|S10')],
#  [1965, array(['two', 'male', 'children', 'jumping', 'on', 'a', 'trampoline'],
#         dtype='|S10')],
#  [1965, array(['the', 'children', 'are', 'jumping'], dtype='|S8')],
#  [1965,
#   array(['two', 'players', 'are', 'playing', 'on', 'ground'], dtype='|S7')],
#  [1965, array(['men', 'are', 'performing', 'sick', 'trampolin', 'tricks'],
#         dtype='|S10')],
#  [1965, array(['two', 'boys', 'practising', 'some', 'sort', 'of', 'gymnastic',
#          'steps', 'on', 'a', 'spring', 'net'], dtype='|S10')],
#  [1965, array(['the', 'boys', 'are', 'doing', 'trampoline', 'tricks'],
#         dtype='|S10')],
#  [1965,
#   array(['people', 'are', 'jumping', 'on', 'trampolines'], dtype='|S11')],
#  [1965,
#   array(['the', 'people', 'jumping', 'in', 'jumping', 'floor'], dtype='|S7')],
#  [1965, array(['kids', 'are', 'jumping'], dtype='|S7')],
#  [1965,
#   array(['kids', 'are', 'doing', 'flipping', 'tricks', 'on', 'trampolines'],
#         dtype='|S11')],
#  [1965, array(['sick', 'trampoline', 'tricks'], dtype='|S10')],
#  [1965, array(['people', 'are', 'jumping', 'on', 'trampoline'], dtype='|S10')],
#  [1965,
#   array(['guys', 'are', 'practicing', 'trampoline', 'tricks'], dtype='|S10')],
#  [1965, array(['two', 'kids', 'tumble', 'on', 'a', 'backyard', 'trampoline'],
#         dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'a', 'slice', 'of', 'watermelon',
#          'someone', 'is', 'holding', 'over', 'a', 'plate'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'a', 'piece', 'of', 'watermelon'],
#         dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'a', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'a', 'piece', 'of', 'watermelon'],
#         dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'water', 'melon'], dtype='|S6')],
#  [1567,
#   array(['a', 'dog', 'is', 'eating', 'some', 'water', 'melon'], dtype='|S6')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['the', 'dog', 'ate', 'the', 'watermelon'], dtype='|S10')],
#  [1567, array(['the', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'eats', 'watermelon'], dtype='|S10')],
#  [1567, array(['the', 'dog', 'ate', 'some', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'a', 'watermelon'], dtype='|S10')],
#  [1567, array(['a', 'dog', 'is', 'eating', 'watermelon'], dtype='|S10')],
#  [1567,
#   array(['the', 'dog', 'is', 'eating', 'the', 'watermelon'], dtype='|S10')],
#  ...]
